# %% [markdown]
# <a href="https://colab.research.google.com/github/BODUNOVAsofia/python-ai-bodunova-sofia/blob/main/notebooks/week2_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Неделя 2 — Чтение и обработка данных / Week 2 — Data loading and preprocessing
#
# RU: В этом ноутбуке вы будете читать ваш CSV-файл и выполнять базовую обработку данных.
#
# EN: In this notebook you will read your CSV file and perform basic data preprocessing.
