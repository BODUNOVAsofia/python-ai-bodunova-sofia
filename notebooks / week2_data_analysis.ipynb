# %% [markdown]
# <a href="https://colab.research.google.com/github/BODUNOVAsofia/python-ai-bodunova-sofia/blob/main/notebooks%20/%20week2_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Неделя 2 — Чтение и обработка данных / Week 2 — Data loading and preprocessing
#
# RU: В этом ноутбуке вы будете читать ваш CSV-файл и выполнять базовую обработку данных.
#
# EN: In this notebook you will read your CSV file and perform basic data preprocessing.

# %%
# Ваш код здесь / Your code starts here

# %% [markdown]
# RU: Часто полезны следующие библиотеки:
# - pandas as pd
# - numpy as np
# - matplotlib.pyplot as plt
# - seaborn as sns (по желанию)
#
# EN: You will usually need:
# - pandas as pd
# - numpy as np
# - matplotlib.pyplot as plt
# - seaborn as sns (optional)

# %% [markdown]
# # Week 2: Data Analysis
#
# This notebook covers data analysis techniques and methods.
#
# # Неделя 2: Анализ данных
#
# Этот ноутбук охватывает методы и техники анализа данных.
